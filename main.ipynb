# %%
from typing import TypedDict

# %%
class State(TypedDict):
    messages: str

# %%
def chat(state: State) -> State:
    return {"messages" : "I am llana"}

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\UR COMPUTER\Desktop\GenAI\venv\Scripts\python.exe

# %%
import langgraph
print(langgraph.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import langgraph
#       2 print(langgraph.__version__)
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
from langgraph.graph  import  START , END , StateGraph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langgraph.graph  import  START , END , StateGraph
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
graph_builder = StateGraph(State)

# %%
graph_builder.add_node("chat_node",chat)

# %%
graph_builder.add_edge(START , "chat_node")

# %%
graph_builder.add_edge("chat_node",END)

# %%
graph = graph_builder.complete()
